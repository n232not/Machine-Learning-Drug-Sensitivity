# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.layers as Layers

# %%
from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Drug_Responses = pd.read_csv("/content/drive/MyDrive/Processed Data/Processed Drug Response Data/New_Drug_Responses.csv")

# %%
Drug_Responses = Drug_Responses.iloc[: , 1:]
Drug_Responses.set_index("CELL_LINE_NAME")
