# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow.keras as keras

from tensorflow.keras import models, layers
from tensorflow.keras.models import Model

from tensorflow.keras.layers import Dense, Activation, Input, Concatenate

import matplotlib.pyplot as plt
tf.random.set_seed(0)
np.random.seed(0)
from sklearn.model_selection import KFold, StratifiedKFold
from IPython.display import clear_output

# %%
from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/drive', force_remount=True)
# Out:
# Drive not mounted, so nothing to flush and unmount.
# Mounted at /content/drive

# %%
mRNA_Unscaled = pd.read_csv("/content/drive/MyDrive/Processed Data/Processed mRNA/New_mRNA.csv")
miRNA_Unscaled = pd.read_csv("/content/drive/MyDrive/Processed Data/Processed miRNA/New_miRNA.csv")
Protein_Unscaled = pd.read_csv("/content/drive/MyDrive/Processed Data/Processed Protein/New_Protein.csv")

# %%
Drugs = pd.read_csv("/content/drive/MyDrive/Processed Data/Processed Drug Response Data/New_Drug_Responses.csv")
Morganfps = pd.read_csv("/content/drive/MyDrive/Processed Data/Processed Drug Response Data/Fingerprints.csv")

# %%
mRNA_Unscaled = mRNA_Unscaled.iloc[: , 1:]
miRNA_Unscaled = miRNA_Unscaled.iloc[: , 1:]
Protein_Unscaled = Protein_Unscaled.iloc[: , 1:]
Drugs = Drugs.iloc[: , 2:]

# %%
Combined_encoder = models.load_model("/content/drive/MyDrive/Models/Combined_Autoencoders/Combined_Unscaled_encoder.h5")

# %%
miRNA_Unscaled.head()
# Out:
#   CELL_LINE_NAME  hsa-let-7b  ...  kshv-miR-K12-5  kshv-miR-K12-8
# 0          22RV1    3.882289  ...        2.190418        1.834144
# 1          22RV1         NaN  ...             NaN             NaN
# 2          22RV1         NaN  ...             NaN             NaN
# 3          22RV1         NaN  ...             NaN             NaN
# 4          22RV1         NaN  ...             NaN             NaN
#
# [5 rows x 225 columns]
